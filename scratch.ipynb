# %%
# from cot_transparency.streaming.tasks import StreamingTaskOutput
from cot_transparency.data_models.models import TaskOutput
from cot_transparency.json_utils.read_write import read_jsonl_file_into_basemodel
    
# StreamingTaskOutput

# %%
x = read_jsonl_file_into_basemodel('experiments/automated_prompt_variant_generation/v1/results/ft:gpt-3.5-turbo-0613:academicsnyuperez::8IWSEki9.jsonl', StreamingTaskOutput)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/milesturpin/Dev/nyu/cot-transparency/scratch.ipynb Cell 2 line 1
# ----> <a href='vscode-notebook-cell:/Users/milesturpin/Dev/nyu/cot-transparency/scratch.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> x = read_jsonl_file_into_basemodel('experiments/automated_prompt_variant_generation/v1/results/ft:gpt-3.5-turbo-0613:academicsnyuperez::8IWSEki9.jsonl', StreamingTaskOutput)
#
# NameError: name 'StreamingTaskOutput' is not defined

# %%
import json
import pandas as pd

# %%
df = pd.read_csv('/Users/milesturpin/Downloads/mistake_following_for_mistake_model_75-25-10k.csv')

# %%
pd.set_option('display.max_colwidth', 2000)

# %%
df
# Out:
#      Unnamed: 0                                                      model  \
# 0          2301  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 1          2302  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 2          2303  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 3          2305  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 4          2306  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# ..          ...                                                        ...
# 158        3124  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 159        3132  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 160        3149  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 161        3205  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
# 162        3243  ft:gpt-3.5-turbo-0613:academicsnyuperez:qma75-25:836CTiOE
#
#      mistake_influence  \
# 0                    1
# ...
